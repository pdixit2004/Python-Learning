# %%
print("Python".find("o"))
# Out:
# 4

# %%
print("AI".upper())
# Out:
# AI

# %%
name="Python"

print(len(name))
# Out:
# 6

# %%
name="Python"

print(name[-2])
# Out:
# o

# %%
name="Python"

print(name[2])
# Out:
# t

# %%
name = input("enter your name : ")
if (len(name)>=5):
    if (" " not in name):
        print("Username Accepted")
    else:
        print("Username Rejected")
else:
    print("Username Rejected")
# Out:
# Username Accepted

# %%
name = "Prakhar Dixit"
print(name.replace(" ","_"))
# Out:
# Prakhar_Dixit

# %%
name = "Prakhar"
print(len(name))
print("The last character is : ", name[-1])
print("The last character is : ", name[len(name)-1])
# Out:
# 7
# The last character is :  r
# The last character is :  r

# %%
name = "Prakhar"
print("Tell me whether A exists in name or not : ", "A" in name)
# Out:
# Tell me whether A exists in name or not :  False

# %%
sentence = "Bengaluru is a very beautiful city in India"
print(sentence.count("i"))
# Out:
# 5

# %%
name = "Prakhar dixit"
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# PRAKHAR DIXIT
# prakhar dixit
# Prakhar Dixit

# %%
city = "Bengaluru"
print(len(city))
# Out:
# 9

# %%
name = "Prakhar"
print(name[0])
print(name[6])
# Out:
# P
# r
