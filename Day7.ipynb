# %%
total = 0

for i in range(1, 6):
    if i % 2 == 0:
        total += i

print(total)
# Out:
# 6

# %%
my_list = []
for i in range(1,6):
    num = input("Enter the numbers to be entered in list : ")
    my_list.append(num)
print(my_list)
my_list.sort()
print(my_list)
# Out:
# ['23', '10', '99', '34', '5']
# ['10', '23', '34', '5', '99']

# %%
colors = ["red", "green", "blue", "yellow"]
print(len(colors))
print(colors[0])
print(colors[3])
# Out:
# 4
# red
# yellow
